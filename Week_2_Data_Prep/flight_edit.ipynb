# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/User/AppData/Local/Packages/Microsoft.MicrosoftEdge_8wekyb3d8bbwe/TempState/Downloads/flights (1).csv')

# %%
df
# Out:
#         year  month   day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013    1.0   1.0     517.0        2.0     830.0       11.0      UA
# 1       2013    1.0   1.0     533.0        4.0     850.0       20.0      UA
# 2       2013    1.0   1.0     542.0        2.0     923.0       33.0      AA
# 3       2013    1.0   1.0     554.0       -6.0     812.0      -25.0      DL
# 4       2013    1.0   1.0     554.0       -4.0     740.0       12.0      UA
# ...      ...    ...   ...       ...        ...       ...        ...     ...
# 153336  2013    9.0  13.0    1835.0       15.0    2153.0        8.0      DL
# 153337  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0      DL
# 153338  2013    9.0  13.0    1840.0       11.0    2204.0       21.0      UA
# 153339  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0      AA
# 153340  2013    NaN   NaN       NaN        NaN       NaN        NaN     NaN
#
# ...

# %%
df.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013    1.0  1.0     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013    1.0  1.0     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013    1.0  1.0     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013    1.0  1.0     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013    1.0  1.0     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0  1545.0    EWR  IAH     227.0    1400.0   5.0    17.0
# 1  1714.0    LGA  IAH     227.0    1416.0   5.0    33.0
# 2  1141.0    JFK  MIA     160.0    1089.0   5.0    42.0
# 3   461.0    LGA  ATL     116.0     762.0   5.0    54.0
# 4  1696.0    EWR  ORD     150.0     719.0   5.0    54.0

# %%
df.tail()
# Out:
#         year  month   day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 153336  2013    9.0  13.0    1835.0       15.0    2153.0        8.0      DL
# 153337  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0      DL
# 153338  2013    9.0  13.0    1840.0       11.0    2204.0       21.0      UA
# 153339  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0      AA
# 153340  2013    NaN   NaN       NaN        NaN       NaN        NaN     NaN
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# 153336  N947DL    83.0    JFK  MIA     147.0    1089.0  18.0    35.0
# 153337  N173DZ    87.0    JFK  ATL     105.0     760.0  18.0    39.0
# 153338  N17233  1526.0    EWR  LAX     331.0    2454.0  18.0    40.0
# 153339  N3DBAA   119.0    EWR  LAX     323.0    2454.0  18.0    41.0
# 153340     NaN     NaN    NaN  NaN       NaN       NaN   NaN     NaN

# %%
df.shape
# Out:
# (153341, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153341 entries, 0 to 153340
# Data columns (total 16 columns):
# year         153341 non-null int64
# month        153340 non-null float64
# day          153340 non-null float64
# dep_time     151040 non-null float64
# dep_delay    151040 non-null float64
# arr_time     150900 non-null float64
# arr_delay    150571 non-null float64
# carrier      153340 non-null object
# tailnum      151931 non-null object
# flight       153340 non-null float64
# origin       153340 non-null object
# dest         153340 non-null object
# air_time     150571 non-null float64
# distance     153340 non-null float64
# hour         151040 non-null float64
# minute       151040 non-null float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 18.7+ MB

# %%
df['carrier']
# Out:
# 0          UA
# 1          UA
# 2          AA
# 3          DL
# 4          UA
#          ...
# 153336     DL
# 153337     DL
# 153338     UA
# 153339     AA
# 153340    NaN
# Name: carrier, Length: 153341, dtype: object

# %%
df[['origin', 'dest']]
# Out:
#        origin dest
# 0         EWR  IAH
# 1         LGA  IAH
# 2         JFK  MIA
# 3         LGA  ATL
# 4         EWR  ORD
# ...       ...  ...
# 153336    JFK  MIA
# 153337    JFK  ATL
# 153338    EWR  LAX
# 153339    EWR  LAX
# 153340    NaN  NaN
#
# [153341 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'dep_delay', 'arr_time',
#        'arr_delay', 'carrier', 'tailnum', 'flight', 'origin', 'dest',
#        'air_time', 'distance', 'hour', 'minute'],
#       dtype='object')

# %%
df.iloc[4]
# Out:
# year           2013
# month             1
# day               1
# dep_time        554
# dep_delay        -4
# arr_time        740
# arr_delay        12
# carrier          UA
# tailnum      N39463
# flight         1696
# origin          EWR
# dest            ORD
# air_time        150
# distance        719
# hour              5
# minute           54
# Name: 4, dtype: object

# %%
df.iloc[[3, 4]]
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 3  2013    1.0  1.0     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013    1.0  1.0     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 3   461.0    LGA  ATL     116.0     762.0   5.0    54.0
# 4  1696.0    EWR  ORD     150.0     719.0   5.0    54.0

# %%
df.iloc[[1, 4]]
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 1  2013    1.0  1.0     533.0        4.0     850.0       20.0      UA  N24211
# 4  2013    1.0  1.0     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 1  1714.0    LGA  IAH     227.0    1416.0   5.0    33.0
# 4  1696.0    EWR  ORD     150.0     719.0   5.0    54.0

# %%
df.loc[2]
# Out:
# year           2013
# month             1
# day               1
# dep_time        542
# dep_delay         2
# arr_time        923
# arr_delay        33
# carrier          AA
# tailnum      N619AA
# flight         1141
# origin          JFK
# dest            MIA
# air_time        160
# distance       1089
# hour              5
# minute           42
# Name: 2, dtype: object

# %%
df.loc[[1, 4]]
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 1  2013    1.0  1.0     533.0        4.0     850.0       20.0      UA  N24211
# 4  2013    1.0  1.0     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 1  1714.0    LGA  IAH     227.0    1416.0   5.0    33.0
# 4  1696.0    EWR  ORD     150.0     719.0   5.0    54.0

# %%
df.set_index('tailnum', inplace=True)

# %%
df
# Out:
#          year  month   day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# tailnum
# N14228   2013    1.0   1.0     517.0        2.0     830.0       11.0      UA
# N24211   2013    1.0   1.0     533.0        4.0     850.0       20.0      UA
# N619AA   2013    1.0   1.0     542.0        2.0     923.0       33.0      AA
# N668DN   2013    1.0   1.0     554.0       -6.0     812.0      -25.0      DL
# N39463   2013    1.0   1.0     554.0       -4.0     740.0       12.0      UA
# ...       ...    ...   ...       ...        ...       ...        ...     ...
# N947DL   2013    9.0  13.0    1835.0       15.0    2153.0        8.0      DL
# N173DZ   2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0      DL
# N17233   2013    9.0  13.0    1840.0       11.0    2204.0       21.0      UA
# N3DBAA   2013    9.0  13.0    1841.0       -9.0    2214.0       14.0      AA
# NaN      2013    NaN   NaN       NaN        NaN       NaN        NaN     NaN
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#        tailnum  year  month   day  dep_time  dep_delay  arr_time  arr_delay  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
index_col='Num'

# %%
df
# Out:
#        tailnum  year  month   day  dep_time  dep_delay  arr_time  arr_delay  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
df.columns= [x.upper() for x in df.columns]
df
# Out:
#        TAILNUM  YEAR  MONTH   DAY  DEP_TIME  DEP_DELAY  ARR_TIME  ARR_DELAY  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
df
# Out:
#        TAILNUM  YEAR  MONTH   DAY  DEP_TIME  DEP_DELAY  ARR_TIME  ARR_DELAY  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
df.columns= [x.lower() for x in df.columns]

# %%
df
# Out:
#        tailnum  year  month   day  dep_time  dep_delay  arr_time  arr_delay  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
df.columns= df.columns.str.replace('_','-')
df
# Out:
#        tailnum  year  month   day  dep-time  dep-delay  arr-time  arr-delay  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
df.columns= df.columns.str.replace('-', '_')
df
# Out:
#        tailnum  year  month   day  dep_time  dep_delay  arr_time  arr_delay  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
df.rename(columns= {'origin': 'start', 'dest': 'end'})
# Out:
#        tailnum  year  month   day  dep_time  dep_delay  arr_time  arr_delay  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
df
# Out:
#        tailnum  year  month   day  dep_time  dep_delay  arr_time  arr_delay  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
df.loc[2]
# Out:
# tailnum      N619AA
# year           2013
# month             1
# day               1
# dep_time        542
# dep_delay         2
# arr_time        923
# arr_delay        33
# carrier          AA
# flight         1141
# origin          JFK
# dest            MIA
# air_time        160
# distance       1089
# hour              5
# minute           42
# Name: 2, dtype: object

# %%
df.loc[2, ['origin', 'dest']]
# Out:
# origin    JFK
# dest      MIA
# Name: 2, dtype: object

# %%
df.loc[2, ['origin']]='LHR'

# %%
df
# Out:
#        tailnum  year  month   day  dep_time  dep_delay  arr_time  arr_delay  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...

# %%
df.loc[2,['origin']]= 'JFK'
df
# Out:
#        tailnum  year  month   day  dep_time  dep_delay  arr_time  arr_delay  \
# 0       N14228  2013    1.0   1.0     517.0        2.0     830.0       11.0
# 1       N24211  2013    1.0   1.0     533.0        4.0     850.0       20.0
# 2       N619AA  2013    1.0   1.0     542.0        2.0     923.0       33.0
# 3       N668DN  2013    1.0   1.0     554.0       -6.0     812.0      -25.0
# 4       N39463  2013    1.0   1.0     554.0       -4.0     740.0       12.0
# ...        ...   ...    ...   ...       ...        ...       ...        ...
# 153336  N947DL  2013    9.0  13.0    1835.0       15.0    2153.0        8.0
# 153337  N173DZ  2013    9.0  13.0    1839.0       -1.0    2052.0      -24.0
# 153338  N17233  2013    9.0  13.0    1840.0       11.0    2204.0       21.0
# 153339  N3DBAA  2013    9.0  13.0    1841.0       -9.0    2214.0       14.0
# 153340     NaN  2013    NaN   NaN       NaN        NaN       NaN        NaN
#
# ...
